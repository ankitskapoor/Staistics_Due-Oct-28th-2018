# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 1.	Read the data set and replace dashes with 0 to make sure you can perform arithmetic operations on the data. (2.5 points)

DF = pd.read_csv(r"C:\Users\Ankit Kapoor\Desktop\AI ML\Oct 2018\Statistics\Home Work\laliga.csv")
DF.head(5)
# Out:
#    Pos             Team  Seasons  Points  GamesPlayed  GamesWon  GamesDrawn  \
# 0    1      Real Madrid       86    4385         2762      1647         552
# 1    2        Barcelona       86    4262         2762      1581         573
# 2    3  Atletico Madrid       80    3442         2614      1241         598
# 3    4         Valencia       82    3386         2664      1187         616
# 4    5  Athletic Bilbao       86    3368         2762      1209         633
#
#    GamesLost  GoalsFor  GoalsAgainst  Champion  Runner-up  Third  Fourth  \
# 0        563      5947          3140        33         23      8       8
# 1        608      5900          3114        25         25     12      12
# 2        775      4534          3309        10          8     16       9
# 3        861      4398          3469         6          6     10      11
# 4        920      4631          3700         8          7     10       5
#
#    Fifth  Sixth   T  Debut Since/LastApp  BestPosition
# ...

# %%
DF.tail(5)
# Out:
#     Pos              Team  Seasons  Points  GamesPlayed  GamesWon  GamesDrawn  \
# 56   57             Xerez        1      34           38         8          10
# 57   58            Condal        1      22           30         7           8
# 58   59   Atletico Tetuan        1      19           30         7           5
# 59   60  Cultural Leonesa        1      14           30         5           4
# 60   61            Girona        1       0            0         0           0
#
#     GamesLost  GoalsFor  GoalsAgainst  Champion  Runner-up  Third  Fourth  \
# 56         20        38            66         0          0      0       0
# 57         15        37            57         0          0      0       0
# 58         18        51            85         0          0      0       0
# 59         21        34            65         0          0      0       0
# 60          0         0             0         0          0      0       0
#
# ...

# %%
DF.shape
# Out:
# (61, 20)

# %%
DF['Debut'].dtype
# Out:
# dtype('int64')

# %%
DF['Debut'].astype('float')
DF.head(5)
# Out:
#    Pos             Team  Seasons  Points  GamesPlayed  GamesWon  GamesDrawn  \
# 0    1      Real Madrid       86    4385         2762      1647         552
# 1    2        Barcelona       86    4262         2762      1581         573
# 2    3  Atletico Madrid       80    3442         2614      1241         598
# 3    4         Valencia       82    3386         2664      1187         616
# 4    5  Athletic Bilbao       86    3368         2762      1209         633
#
#    GamesLost  GoalsFor  GoalsAgainst  Champion  Runner-up  Third  Fourth  \
# 0        563      5947          3140        33         23      8       8
# 1        608      5900          3114        25         25     12      12
# 2        775      4534          3309        10          8     16       9
# 3        861      4398          3469         6          6     10      11
# 4        920      4631          3700         8          7     10       5
#
#    Fifth  Sixth   T  Debut Since/LastApp  BestPosition
# ...

# %%
# 2.Print all the teams which have started playing between 1930-1980. (5 points)

DF1 =DF[(DF['Debut'] >= 1930) & (DF['Debut'] <= 1980)]
DF1['Team']
# Out:
# 3                Valencia
# 5                 Sevilla
# 8                Zaragoza
# 9              Real Betis
# 10    Deportivo La Coruna
# 11             Celta Vigo
# 12             Valladolid
# 14         Sporting Gijon
# 15                Osasuna
# 16                 Malaga
# 17                 Oviedo
# 18               Mallorca
# 19             Las Palmas
# 21                Granada
# 22         Rayo Vallecano
# 23                  Elche
# 25               Hercules
# 26               Tenerife
# 27                 Murcia
# 28                 Alaves
# 29                Levante
# 30              Salamanca
# 31               Sabadell
# 32                  Cadiz
# 34              Castellon
# 37                Cordoba
# 39             Recreativo
# 40              Burgos CF
# 41             Pontevedra
# 46              Gimnastic
# 49               Alcoyano
# 50                   Jaen
# 52             AD Almeria
# 54                 Lleida
# 57                 Condal
# ...

# %%
# 3.	Print the list of teams which came Top 5 in terms of points (2.5 points)

DF2 = DF [(DF['Champion']>0) & (DF['Runner-up']>0) & (DF['Third']>0) & (DF['Fourth']>0) & (DF['Fifth']>0)]
DF2 ['Team']
# Out:
# 0        Real Madrid
# 1          Barcelona
# 2    Atletico Madrid
# 3           Valencia
# 4    Athletic Bilbao
# 5            Sevilla
# 7      Real Sociedad
# Name: Team, dtype: object

# %%
4. # Write a function with name “Goal_diff_count” 

DF['Goal_diff_count'] = DF ['GoalsFor'] - DF ['GoalsAgainst']
DF.head (5)
# Out:
#    Pos             Team  Seasons  Points  GamesPlayed  GamesWon  GamesDrawn  \
# 0    1      Real Madrid       86    4385         2762      1647         552
# 1    2        Barcelona       86    4262         2762      1581         573
# 2    3  Atletico Madrid       80    3442         2614      1241         598
# 3    4         Valencia       82    3386         2664      1187         616
# 4    5  Athletic Bilbao       86    3368         2762      1209         633
#
#    GamesLost  GoalsFor  GoalsAgainst       ...         Runner-up  Third  \
# 0        563      5947          3140       ...                23      8
# 1        608      5900          3114       ...                25     12
# 2        775      4534          3309       ...                 8     16
# 3        861      4398          3469       ...                 6     10
# 4        920      4631          3700       ...                 7     10
#
#    Fourth  Fifth  Sixth   T  Debut  Since/LastApp BestPosition  \
# ...

# %%
DF10 = DF[(DF['Goal_diff_count'].max()) & (DF['Team'])]
DF10['Team']
# Out:
# 0    True
# Name: Team, dtype: bool

# %%
DF11 = DF[(DF['Goal_diff_count'].min()) & (DF['Team'])]
DF11 ['Team']
# Out:
# 0    True
# Name: Team, dtype: bool

# %%
# 5.	Create a new column with name “Winning Percent” and append it to the data set (5 points)Percentage of Winning = (GamesWon / GamesPlayed)*100. If there are any numerical error, replace it with 0%


DF['Winning Percent'] = 100*DF['GamesWon']/DF['GamesPlayed']
DF.head(5)
# Out:
#    Pos             Team  Seasons  Points  GamesPlayed  GamesWon  GamesDrawn  \
# 0    1      Real Madrid       86    4385         2762      1647         552
# 1    2        Barcelona       86    4262         2762      1581         573
# 2    3  Atletico Madrid       80    3442         2614      1241         598
# 3    4         Valencia       82    3386         2664      1187         616
# 4    5  Athletic Bilbao       86    3368         2762      1209         633
#
#    GamesLost  GoalsFor  GoalsAgainst       ...         Third  Fourth  Fifth  \
# 0        563      5947          3140       ...             8       8      3
# 1        608      5900          3114       ...            12      12      4
# 2        775      4534          3309       ...            16       9      7
# 3        861      4398          3469       ...            10      11     10
# 4        920      4631          3700       ...            10       5      8
#
# ...

# %%
# Answer for Top 5 team basis winning percent.

DF3 = DF [(DF['Winning Percent']>42) & (DF['Team'])]
DF3 ['Team']
# Out:
# 0        Real Madrid
# 1          Barcelona
# 2    Atletico Madrid
# 3           Valencia
# 4    Athletic Bilbao
# Name: Team, dtype: object

# %%
# 6.Group teams based on their “Best position” and print the sum of their points for all positions (5 points)

DF.groupby('BestPosition')

# %%
DF4 = DF.groupby("BestPosition")

# %%
DF5 = DF4.sum().head(5)
DF5 ['Points']
# Out:
# BestPosition
# 1    27933
# 2     6904
# 3     5221
# 4     6563
# 5     1884
# Name: Points, dtype: int64
